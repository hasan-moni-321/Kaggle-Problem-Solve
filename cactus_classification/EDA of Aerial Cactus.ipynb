# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import os
from PIL import Image
#from transformers import Transformer
#import kekas

import torch
import torch.nn as nn
import torch.functional as F

from sklearn.model_selection import train_test_split

import warnings
warnings.filterwarnings('ignore')

# %%
train = pd.read_csv("/home/hasan/Data Set/aerial-cactus-identification/train.csv")

train_image = "/home/hasan/Data Set/aerial-cactus-identification/train/"
test_image = "/home/hasan/Data Set/aerial-cactus-identification/test/"

# %%
train.head()
# Out:
#                                      id  has_cactus
# 0  0004be2cfeaba1c0361d39e2b000257b.jpg           1
# 1  000c8a36845c0208e833c79c1bffedd1.jpg           1
# 2  000d1e9a533f62e55c289303b072733d.jpg           1
# 3  0011485b40695e9138e92d0b3fb55128.jpg           1
# 4  0014d7a11e90b62848904c1418fc8cf2.jpg           1

# %%
train.shape
# Out:
# (17500, 2)

# %%
train.has_cactus.nunique()
# Out:
# 2

# %%
train.has_cactus.value_counts()
# Out:
# 1    13136
# 0     4364
# Name: has_cactus, dtype: int64

# %%
sns.countplot(train['has_cactus'])
# Out:
# <AxesSubplot:xlabel='has_cactus', ylabel='count'>

# %%
train_img = os.listdir(train_image)

fig = plt.figure(figsize=(25,8))
for idx, img in enumerate(np.random.choice(train_img, 20)):
    ax = fig.add_subplot(4, 20//4, idx+1, xticks=[], yticks=[])
    im = Image.open(train_image + img)
    plt.imshow(im)
    lab = train.loc[train['id']==img, 'has_cactus'].values[0]
    ax.set_title(f'label:{lab}')
